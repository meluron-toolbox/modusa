# %% [markdown]
# # Signal1D
# A class to represent 1D signals (uniform/non-uniform)

# %% [markdown]
# How to create a new **Signal1D** instance? \
# There are various ways to create an axis,
# 1. Directly invoke the constructor.
# 2. Use provided APIs to create different types of axis.

# %% [markdown]
# ## Object Instantiation

# %% [markdown]
# ### With Constructor

# %%
import modusa as ms
import numpy as np

# %%
s = ms.signal1D(np.random.random(100))
print(s)
s.print_info()
# Out:
# ...
# Data: Signal1D([0.2470987 , 0.84783519, ..., 0.94612568, 0.05774789], shape=(100,), label=Data)
# -----
# Axis: (SAx([ 0,  1,  2, ..., 97, 98, 99], shape=(100,), label=X (index)),)
# =====
# --------------------------------------------------
# Title: Signal 1D
# --------------------------------------------------
# Type                : Signal1D
# Shape               : (100,)
# Inheritance         : ABC → ModusaSignal → Signal1D
# ...

# %% [markdown]
# ### With built-in APIs
# Right now, we do no offer any custom API for this but we might later add on.

# %% [markdown]
# ## Visualisation
# We have a dedicate `.plot` method for `Signal1D` instance.

# %%
s.plot()

# %% [markdown]
# ## Math Operations
# We provide many operations for `Signal1D` instance.

# %% [markdown]
# ### Comparison
# Like >, <=, ==, !=, ...

# %%
print(s > 0.2)
display((s > 0.2).plot())
# Out:
# ...
# Data: Signal1D([ True,  True, ...,  True, False], shape=(100,), label=Data)
# -----
# Axis: (SAx([ 0,  1,  2, ..., 97, 98, 99], shape=(100,), label=X (index)),)
# =====

# %%
s[s>0.1].plot()

# %% [markdown]
# ### Basic Arithmetic
# Like +, -, ...

# %%
s1.plot()

# %%
s1.plot()

# %%
display(s.plot())
display((s + s).plot())
display((s - s).plot())
display((s * s).plot())
display((s / s).plot())

# %% [markdown]
# ### Unary Transformation
# Like sin, cos, log, ...

# %%
t = np.arange(10) / sr
y = np.sin(2*np.pi*f*t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 y = mx^2 + c
#
# NameError: name 'mx' is not defined

# %%
y = ms.tds(data=np.sin())
