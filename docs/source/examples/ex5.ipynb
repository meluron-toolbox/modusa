# %%
from modusa.io import AudioLoader
from modusa.generators import AudioWaveformGenerator
from modusa.tools.plotter import Plotter

# %%
signal1 = AudioWaveformGenerator.generate_sinusoid(f=10, duration=4, sr=10000)
signal2 = AudioWaveformGenerator.generate_sinusoid(f=20, duration=4, sr=10000)
signal = signal1 | signal2

# %%
signal.plot(highlight_regions=[(3.5, 4.5, "Transition")], legend=("Mixed signals", "upper right"))

# %%
spec = signal.to_spectrogram(n_fft=1024).magnitude
spec
# Out:
# Signal([[163.8, 18.59, 37.08, ..., 3.529, 3.676, 74.4],
#  [140.2, 256.9, 256.8, ..., 119.2, 119.3, 153.4],
#  [85.44, 132.4, 132.4, ..., 255.5, 255.4, 192.2],
#  ...,
#  [0.001571, 2.171e-09, 2.157e-09, ..., 4.432e-09, 4.44e-09, 0.002682],
#  [0.001571, 1.088e-09, 1.088e-09, ..., 4.251e-09, 4.383e-09, 0.002682],
#  [0.001571, 8.39e-11, 1.673e-10, ..., 4.189e-09, 4.364e-09, 0.002682]], shape=(513, 157), kind=Spectrogram)

# %%
spec.plot(highlight_regions=[(3.5, 4.5, "Transition")], ylim=(0, 100))

# %%
signal.play(regions=[(0, 5), (6, 7)])
# Out:
# <h4>Sinusoid (10.0 Hz) | Sinusoid (20.0 Hz)</h4>
# 		<div style="display:inline-block; border:1px solid #ccc; border-radius:6px; overflow:hidden;">
# 			<table style="border-collapse:collapse;">
# 				<tr style="background-color:#f2f2f2;">
# 					<th style="text-align:left; padding:6px 12px;">Clip</th>
# 					<td style='text-align:center; border-right:1px solid #ccc; padding:6px;'>1</td><td style='text-align:center; border-right:1px solid #ccc; padding:6px;'>2</td>
# 				</tr>
# 				<tr style="background-color:#fcfcfc;">
# 					<th style="text-align:left; padding:6px 12px;">Timing</th>
# 					<td style='text-align:center; border-right:1px solid #ccc; padding:6px;'>0.00s → 5.00s</td><td style='text-align:center; border-right:1px solid #ccc; padding:6px;'>6.00s → 7.00s</td>
# 				</tr>
# 				<tr>
# 					<th style="text-align:left; padding:6px 12px;">Player</th>
# 					<td style='padding:6px;'>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td><td style='padding:6px;'>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td>
# 				</tr>
# 			</table>
# 		</div>

# %%
spec = signal.to_spectrogram(n_fft=256, hop_length=16)

# %%
spec.f
# Out:
# array([   0.    ,   39.0625,   78.125 ,  117.1875,  156.25  ,  195.3125,
#         234.375 ,  273.4375,  312.5   ,  351.5625,  390.625 ,  429.6875,
#         468.75  ,  507.8125,  546.875 ,  585.9375,  625.    ,  664.0625,
#         703.125 ,  742.1875,  781.25  ,  820.3125,  859.375 ,  898.4375,
#         937.5   ,  976.5625, 1015.625 , 1054.6875, 1093.75  , 1132.8125,
#        1171.875 , 1210.9375, 1250.    , 1289.0625, 1328.125 , 1367.1875,
#        1406.25  , 1445.3125, 1484.375 , 1523.4375, 1562.5   , 1601.5625,
#        1640.625 , 1679.6875, 1718.75  , 1757.8125, 1796.875 , 1835.9375,
#        1875.    , 1914.0625, 1953.125 , 1992.1875, 2031.25  , 2070.3125,
#        2109.375 , 2148.4375, 2187.5   , 2226.5625, 2265.625 , 2304.6875,
#        2343.75  , 2382.8125, 2421.875 , 2460.9375, 2500.    , 2539.0625,
#        2578.125 , 2617.1875, 2656.25  , 2695.3125, 2734.375 , 2773.4375,
#        2812.5   , 2851.5625, 2890.625 , 2929.6875, 2968.75  , 3007.8125,
#        3046.875 , 3085.9375, 3125.    , 3164.0625, 3203.125 , 3242.1875,
#        3281.25  , 3320.3125, 3359.375 , 3398.4375, 3437.5   , 3476.5625,
#        3515.625 , 3554.6875, 3593.75  , 3632.8125, 3671.875 , 3710.9375,
#        3750.    , 3789.0625, 3828.125 , 3867.1875, 3906.25  , 3945.3125,
#        3984.375 , 4023.4375, 4062.5   , 4101.5625, 4140.625 , 4179.6875,
#        4218.75  , 4257.8125, 4296.875 , 4335.9375, 4375.    , 4414.0625,
#        4453.125 , 4492.1875, 4531.25  , 4570.3125, 4609.375 , 4648.4375,
#        4687.5   , 4726.5625, 4765.625 , 4804.6875, 4843.75  , 4882.8125,
#        4921.875 , 4960.9375, 5000.    ])

# %%
spec.magnitude.plot(highlight=[(3.5, 4.5, "Transition")], ylim=(0, 50))
